# %% [markdown]
# # Preparation

# %%
# We'll need some modules
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Let's load and check out the data
movies = pd.read_csv("Data/movies.csv", encoding="latin1")
movies.head()
# Out:
#              Actor            Movie
# 0   Chinlund, Nick    100 Mile Rule
# 1  Mavity, Abigail    100 Mile Rule
# 2  McKean, Michael    100 Mile Rule
# 3      Carter, Jim  102 Dalmatians
# 4    Crompton, Ben  102 Dalmatians

# %%
# In how many movies did Kevin Bacon play?
sum(movies.Actor == "Bacon, Kevin")
# Out:
# 5

# %% [markdown]
# # Let's start with the graph

# %%
# A list of tuples is needed to create the edges.
edges = zip(movies.Actor, movies.Movie)

# %%
# An empty graph
G = nx.Graph()

# %%
# Adding actors as nodes
G.add_nodes_from(movies.Actor, color="red")
# and movies as nodes
G.add_nodes_from(movies.Movie, color="blue")

# %%
# Add edges
G.add_edges_from(edges)

# %% [markdown]
# # Graph exploration

# %%
# Let's see what we got.
print("Total number of actors and movies: {}".format(G.number_of_nodes()))
print("Total number of edges: {}".format(G.number_of_edges()))
# Out:
# Total number of actors and movies: 238
# Total number of edges: 257

# %%
# How many distinct actors and movies?
print("Distinct number of actors: {}".format(len(set(movies.Actor))))
print("Distinct number of movies: {}".format(len(set(movies.Movie))))
# Out:
# Distinct number of actors: 150
# Distinct number of movies: 88

# %%
# some graph drawings, because we can
nx.draw(G)

# %%
nx.draw_random(G)

# %%
nx.draw_circular(G)

# %%
# movies starring Kevin Bacon
movies_with_bacon = G.neighbors("Bacon, Kevin")
movies_with_bacon
# Out:
# ['Friday The 13th Parts I - VIII: From Crystal Lake To Manhattan ',
#  'Wild Things ',
#  'Apollo 13 ',
#  'Crazy Stupid Love',
#  'Tremors ']

# %%
# actors playing together with Kevin Bacon in movies
for movie in movies_with_bacon:
    actors_with_bacon = G.neighbors(movie)
    print("{}:\n {}".format(movie, "\n ".join(actors_with_bacon)))
# Out:
# Friday The 13th Parts I - VIII: From Crystal Lake To Manhattan :
#  Crosby, Harry
#  Nelson, Mark
#  Bacon, Kevin
#  Everhart, Rex
# Wild Things :
#  Richards, Denise
#  Campbell, Neve
#  Murray, Bill
#  Russell, Theresa
#  Dillon, Matt
#  Bacon, Kevin
# Apollo 13 :
#  Quinlan, Kathleen
#  Bacon, Kevin
#  Sinise, Gary
# Crazy Stupid Love:
#  Moore, Julianne
#  Bacon, Kevin
#  Carell, Steve
#  Stone, Emma
# Tremors :
#  Bacon, Kevin
#  Shaver, Helen

# %% [markdown]
# # Let's get some bacon numbers

# %%
# get the shortest path for all nodes to Kevin Bacon
p=nx.shortest_path_length(G,source="Bacon, Kevin")
# prepare a dictionary to store the numbers
bacon = dict()
# bacon number magic!
for actor in movies.Actor:
    bacon_nr = int(1 + p[actor]/2)
    bacon[actor] = bacon_nr

# and here they are, all bacon numbers!
print(bacon)
# Out:
# {'Richards, Denise': 2, 'Bransford, Jennifer': 5, 'Myers, Mike': 3, 'Estevez, Joe': 4, 'Johansson, Scarlett': 3, 'Moore, Julianne': 2, 'Kanakaredes, Melina': 5, 'Russell, Theresa': 2, 'Stone, Emma': 2, 'Favreau, Jon': 4, 'Affleck, Casey': 4, 'Zellweger, Renée': 5, 'Carell, Steve': 2, 'Depardieu, Gérard': 5, 'Naudet, Gédéon': 5, 'Ecker, Chris': 4, 'Jiang, Franco': 5, 'Castellano, Richard C.': 5, 'Cioffi, Charles': 5, 'Brolin, James': 3, 'Crosby, Harry': 2, 'Rourke, Mickey': 4, 'Denham, Maurice': 5, 'Barrymore, Drew': 5, 'McCallany, Holt': 5, 'Damon, Matt': 3, 'Kay, Charles': 5, 'Bailey, Eion': 5, 'Sedgwick, Kyra': 5, 'Quinlan, Kathleen': 2, 'Shaver, Helen': 2, 'Caan, Scott': 5, 'Baer, Jean De': 5, 'Jenkins, Noam': 3, 'Leonard, Joshua': 5, 'Armisen, Fred': 3, 'Schreyer, Werner': 5, 'Berridge, Elizabeth': 5, 'Cesario, Jeff': 5, 'Casaliggi, Joseph': 5, 'Carter, Jim': 4, 'Cox, Ronny': 5, 'Chow, Haau Wing': 5, 'Zeta-Jones, Catherine': 5, 'Dalton, Timothy': 5, 'Broadbent, Jim': 5, 'Martin, Steve': 5, 'Affleck, Ben': 3, 'Featherstone, Angela': 4, 'Basinger, Kim': 3, 'Abraham, F. Murray': 5, 'Bonet, Lisa': 5, 'Cain, Gertrude': 4, 'Sinise, Gary': 2, 'Gordon-Levitt, Joseph': 3, 'Cromwell, James': 5, 'Rudd, Paul': 3, 'Nelson, Judd': 5, 'Everhart, Rex': 2, 'McNeice, Ian': 5, 'DiResta, John': 5, 'Barkin, Ellen': 5, 'Ebersole, Christine': 5, 'Ellis, Aunjanue': 5, 'Berkoff, Steven': 5, 'Applegate, Christina': 3, 'Rampling, Charlotte': 5, 'Dillon, Matt': 2, 'McCormack, Will': 5, 'Scott, Adam': 4, 'Aaron, Caroline': 4, 'Sher, Antony': 4, 'Paang, Siu Laan': 5, 'Diesel, Vin': 4, 'Schneider, Dan': 5, 'Clunes, Martin': 4, 'Pacino, Al': 5, 'Crouse, Lindsay': 5, 'Arquette, Alexis': 5, 'Rapaport, Michael': 5, 'Berg, Peter': 4, 'Candy, John': 5, 'Black, Lucas': 4, 'Rogen, Seth': 3, 'McKidd, Kevin': 5, 'Everhart, Angie': 5, 'Scott, Dougray': 5, 'Ruehl, Mercedes': 5, 'Murray, Bill': 2, 'Farmiga, Vera': 5, 'McMillan, Kenneth': 5, 'Meyer, Breckin': 3, 'Díaz, Guillermo': 4, 'Chappelle, David': 4, 'Mathison, Cameron': 3, 'Braithwaite, Jamal': 5, 'Chow, Yu-Hou': 5, 'Burns, Edward': 5, 'Banderas, Antonio': 5, 'McKean, Michael': 4, 'Orser, Leland': 4, 'Campbell, Nicholas': 3, 'David, Eleanor': 5, 'Arkin, Alan': 5, 'Baranski, Christine': 4, 'Crompton, Ben': 5, 'Eziashi, Maynard': 5, 'Davidson, Tommy': 5, 'Rush, Geoffrey': 4, 'Kudrow, Lisa': 5, 'Meredith, Burgess': 4, 'Naudet, Jules': 5, 'Blades, Rubén': 4, 'Bancroft, Anne': 5, 'Novakovic, Kresimir': 5, 'Boothe, Powers': 5, 'Murphy, Brittany': 3, 'Nance, Jack': 4, 'Davis, Julie': 5, 'Margulies, David': 4, 'West, Dominic': 5, 'Roden, Karel': 5, 'Clark, Bob': 4, 'Buscemi, Steve': 5, 'Carrey, Jim': 5, 'Bacon, Kevin': 1, 'Astin, Mackenzie': 4, 'Brooks, Avery': 5, 'Ben-Victor, Paul': 4, 'Eminem': 3, 'Donovan, Jeffrey': 5, 'Moriarty, Cathy': 5, 'Campbell, Neve': 2, 'Mavity, Abigail': 5, 'Callow, Simon': 4, 'Dench, Judi': 4, 'McInnerny, Tim': 5, 'Farley, Chris': 5, 'Esterman, Laura': 3, 'Baker, Kenny': 5, 'Niro, Robert De': 4, 'Feore, Colm': 5, 'Farrell, Colin': 4, 'Siemaszko, Nina': 5, 'Crystal, Billy': 5, 'Chinlund, Nick': 5, 'Dern, Bruce': 4, 'Nelson, Mark': 2, 'Crowley, David L.': 3, 'Sassaman, Nicole': 4}

# %% [markdown]
# ## Quiztime: Week 7 of EX101x

# %%
# Assignment 7.5
print("Kim Basinger: {}".format(bacon["Basinger, Kim"]))
print("Steve Buscemi: {}".format(bacon["Buscemi, Steve"]))
# Out:
# Kim Basinger: 3
# Steve Buscemi: 5

# %%
# Lisa Kudrow as source...let's make a function first.

# get the shortest path for all nodes to anyone
def bacon_anyone(anyone):
    p=nx.shortest_path_length(G,source=anyone)
    # prepare a dictionary to store the numbers
    bacon = dict()
    # bacon number magic!
    for actor in movies.Actor:
        bacon_nr = int(1 + p[actor]/2)
        bacon[actor] = bacon_nr
    return bacon

# %%
# Ok then, the Kudrow_number...
kudrow = bacon_anyone("Kudrow, Lisa")

print("Ben Affleck's Kudrow_number: {}".format(kudrow["Affleck, Ben"]))
# Out:
# Ben Affleck's Kudrow_number: 3

# %%
# If we use Matt Damon as a the base (Matt Damon is now Kevin Bacon), what is Elizabeth Berridge’s Damon number?
damon = bacon_anyone("Damon, Matt")

print("Elizabeth Berridge's Damon_number: {}".format(damon["Berridge, Elizabeth"]))
# Out:
# Elizabeth Berridge's Damon_number: 4
